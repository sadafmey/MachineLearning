# %% [markdown]
# ### Simple Financial Tracker (Pandas) – monthly income vs expenses

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Step 1: Create a simple financial dataset
data = {
    "Month": [
        "January", "February", "March", 
        "April", "May", "June"
    ],
    "Income": [3000, 3200, 2800, 3500, 3600, 3300],
    "Expenses": [2500, 2700, 3000, 3200, 3100, 2900]
}
df = pd.DataFrame(data)
print("Financial Data:\n", df)
# Out:
# Financial Data:
#        Month  Income  Expenses
# 0   January    3000      2500
# 1  February    3200      2700
# 2     March    2800      3000
# 3     April    3500      3200
# 4       May    3600      3100
# 5      June    3300      2900

# %%
# Step 2: Calculate net savings (Income - Expenses)
df["Savings"] = df["Income"] - df["Expenses"]
print("\nFinancial Data with Savings:\n", df)
# Out:
# Financial Data with Savings:
#        Month  Income  Expenses  Savings
# 0   January    3000      2500      500
# 1  February    3200      2700      500
# 2     March    2800      3000     -200
# 3     April    3500      3200      300
# 4       May    3600      3100      500
# 5      June    3300      2900      400

# %%
# Step 3: Plot Income vs Expenses
plt.figure(figsize=(10, 6))
plt.plot(df["Month"], df["Income"], marker='o', label="Income")
plt.plot(df["Month"], df["Expenses"], marker='o', label="Expenses")
plt.plot(df["Month"], df["Savings"], marker='o', linestyle='--', label="Savings")
plt.title("Monthly Income vs Expenses")
plt.xlabel("Month")
plt.ylabel("Amount ($)")
plt.legend()
plt.grid(True)
plt.show()
